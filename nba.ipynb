# %%
import numpy as np
import pandas as pd
import requests
import random
import time
from io import StringIO

# %%
teams =['ATL']

# %%
teams = [
    'ATL', 'BOS', 'BRK', 'CHO', 'CHI', 'DAL', 'DEN', 'DET', 'GSW', 'HOU',
    'CLE', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NOP', 'NYK',
    'OKC', 'ORL', 'PHI', 'PHO', 'POR', 'SAC', 'SAS', 'TOR', 'UTA', 'WAS'
]

# %%
team_dict ={
    'ATL': 'Atlanta Hawks'}

# %%
team_dict ={
    'ATL': 'Atlanta Hawks',
    'BOS': 'Boston Celtics',
    'BRK': 'Brooklyn Nets',
    'CHO': 'Charlotte Hornets',
    'CHI': 'Chicago Bulls',
    'CLE': 'Cleveland Cavaliers',
    'DAL': 'Dallas Mavericks',
    'DEN': 'Denver Nuggets',
    'DET': 'Detroit Pistons',
    'GSW': 'Golden State Warriors',
    'HOU': 'Houston Rockets',
    'IND': 'Indiana Pacers',
    'LAC': 'Los Angeles Clippers',
    'LAL': 'Los Angeles Lakers',
    'MEM': 'Memphis Grizzlies',
    'MIA': 'Miami Heat',
    'MIL': 'Milwaukee Bucks',
    'MIN': 'Minnesota Timberwolves',
    'NOP': 'New Orleans Pelicans',
    'NYK': 'New York Knicks',
    'OKC': 'Oklahoma City Thunder',
    'ORL': 'Orlando Magic',
    'PHI': 'Philadelphia 76ers',
    'PHO': 'Phoenix Suns',
    'POR': 'Portland Trail Blazers',
    'SAC': 'Sacramento Kings',
    'SAS': 'San Antonio Spurs',
    'TOR': 'Toronto Raptors',
    'UTA': 'Utah Jazz',
    'WAS': 'Washington Wizards'
}

# %%
seasons =['2024']
#len(seasons)
#print(seasons)

for season in seasons:
  print(season)
# Out:
# 2024

# %%
# Create an empty DataFrame to append
nba_df = pd.DataFrame()

# Iterate through seasons and teams
for season in seasons:
    for team in teams:

        # Set up URL
        url = f'https://www.basketball-reference.com/teams/{team}/{season}/gamelog-advanced/'
        print(url)

        response = requests.get(url, headers={'User-agent': 'Mozilla/5.0'})
        visible_html = response.text.replace('<!--', '').replace('-->', '')

        try:
            df_list = pd.read_html(StringIO(visible_html), header=1)
            if len(df_list) > 1:
                # If playoffs exist, concatenate regular season and playoff data
                df_list[1]['G'] = df_list[1]['G'] + 82  # Offset playoff games
                team_df = pd.concat([df_list[0], df_list[1]], ignore_index=True)
            else:
                team_df = df_list[0]

            # Clean and process DataFrame
            team_df = team_df.dropna(subset=['G'])  # Drop rows where 'G' is NaN
            team_df = team_df[team_df['G'] != 'G']  # Remove header rows
            team_df = team_df.iloc[:, 1:11]  # Keep columns 1 to 11
            team_df = team_df.rename(columns={'Unnamed: 3': 'At', 'Tm': 'OPts', 'Opp.1': 'DPts'})

            # Add computed columns
            team_df['At'] = team_df['At'].apply(lambda x: x if x == '@' else "")
            team_df['Win'] = team_df['W/L'].apply(lambda x: 1 if x == 'W' else 0)
            team_df['Location'] = team_df['At'].apply(lambda x: 'Away' if x == '@' else 'Home')
            team_df.insert(loc =6 , column= 'Location', value=team_df.pop('Location'))
            team_df['Opp_Name'] = team_df['Opp'].apply(lambda x: team_dict.get(x, 'Unknown'))
            team_df.insert(loc =8 , column= 'Opp_Name', value=team_df.pop('Opp_Name'))

            # Insert additional columns
            team_df.insert(0, 'Season', season)
            team_df.insert(2, 'Team', team)
            team_df.insert(3, 'Name', team_dict[team])

            # Append to aggregate DataFrame
            nba_df = pd.concat([nba_df, team_df], ignore_index=True)

        except Exception as e:
            print(f"Failed to process {team} in {season}: {e}")

        # Pause to abide by site rules
        time.sleep(random.randint(4, 6))

# Display the aggregate DataFrame
print(nba_df.shape)
# Out:
# https://www.basketball-reference.com/teams/ATL/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/BOS/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/BRK/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHO/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/CHI/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/DAL/2024/gamelog-advanced/
# Failed to process DAL in 2024: can only concatenate str (not "int") to str
# https://www.basketball-reference.com/teams/DEN/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/DET/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/GSW/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/HOU/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/CLE/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/IND/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAC/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/LAL/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/MEM/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIA/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIL/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/MIN/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/NOP/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/NYK/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/OKC/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/ORL/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHI/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/PHO/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/POR/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAC/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/SAS/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/TOR/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/UTA/2024/gamelog-advanced/
# https://www.basketball-reference.com/teams/WAS/2024/gamelog-advanced/
# (2520, 16)

# %%
nba_df
# Out:
#      Season   G Team                Name        Date At  Opp W/L OPts  \
# 0      2024   1  ATL       Atlanta Hawks  2023-10-25  @  CHO   L  110
# 1      2024   2  ATL       Atlanta Hawks  2023-10-27     NYK   L  120
# 2      2024   3  ATL       Atlanta Hawks  2023-10-29  @  MIL   W  127
# 3      2024   4  ATL       Atlanta Hawks  2023-10-30     MIN   W  127
# 4      2024   5  ATL       Atlanta Hawks  2023-11-01     WAS   W  130
# ...     ...  ..  ...                 ...         ... ..  ...  ..  ...
# 2515   2024  78  WAS  Washington Wizards  2024-04-05     POR   L  102
# 2516   2024  79  WAS  Washington Wizards  2024-04-07  @  TOR   L  122
# 2517   2024  80  WAS  Washington Wizards  2024-04-09  @  MIN   L  121
# 2518   2024  81  WAS  Washington Wizards  2024-04-12     CHI   L  127
# 2519   2024  82  WAS  Washington Wizards  2024-04-14  @  BOS   L  122
#
#      Location DPts                Opp_Name   ORtg   DRtg   Pace  Win
# 0        Away  116       Charlotte Hornets  106.4  112.2  103.4    0
# 1        Home  126         New York Knicks  115.9  121.7  103.5    0
# 2        Away  110         Milwaukee Bucks  123.1  106.6  103.2    1
# 3        Home  113  Minnesota Timberwolves  128.7  114.5   98.7    1
# 4        Home  121      Washington Wizards  117.7  109.6  110.4    1
# ...       ...  ...                     ...    ...    ...    ...  ...
# 2515     Home  108  Portland Trail Blazers  104.4  110.5   97.7    0
# 2516     Away  130         Toronto Raptors  111.1  118.4  109.8    0
# 2517     Away  130  Minnesota Timberwolves  121.0  130.0  100.0    0
# 2518     Home  129           Chicago Bulls  120.8  122.7  105.1    0
# 2519     Away  132          Boston Celtics  114.7  124.1  106.3    0
#
# [2520 rows x 16 columns]

# %%
# Update datatypes
nba_df['G'] = nba_df['G'].astype('int')
nba_df['OPts'] = nba_df['OPts'].astype('int')
nba_df['DPts'] = nba_df['DPts'].astype('int')
nba_df['ORtg'] = nba_df['ORtg'].astype('float')
nba_df['DRtg'] = nba_df['DRtg'].astype('float')
nba_df['Pace'] = nba_df['Pace'].astype('float')

# %%
print(nba_df.info())
(nba_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Season    2520 non-null   object
#  1   G         2520 non-null   int64
#  2   Team      2520 non-null   object
#  3   Name      2520 non-null   object
#  4   Date      2520 non-null   object
#  5   At        2520 non-null   object
#  6   Opp       2520 non-null   object
#  7   W/L       2520 non-null   object
#  8   OPts      2520 non-null   int64
#  9   Location  2520 non-null   object
#  10  DPts      2520 non-null   int64
#  11  Opp_Name  2520 non-null   object
#  12  ORtg      2520 non-null   float64
#  13  DRtg      2520 non-null   float64
#  14  Pace      2520 non-null   float64
#  15  Win       2520 non-null   int64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 315.1+ KB
# None
#   Season  G Team           Name        Date At  Opp W/L  OPts Location  DPts  \
# 0   2024  1  ATL  Atlanta Hawks  2023-10-25  @  CHO   L   110     Away   116
# 1   2024  2  ATL  Atlanta Hawks  2023-10-27     NYK   L   120     Home   126
# 2   2024  3  ATL  Atlanta Hawks  2023-10-29  @  MIL   W   127     Away   110
# 3   2024  4  ATL  Atlanta Hawks  2023-10-30     MIN   W   127     Home   113
# 4   2024  5  ATL  Atlanta Hawks  2023-11-01     WAS   W   130     Home   121
#
#                  Opp_Name   ORtg   DRtg   Pace  Win
# 0       Charlotte Hornets  106.4  112.2  103.4    0
# 1         New York Knicks  115.9  121.7  103.5    0
# 2         Milwaukee Bucks  123.1  106.6  103.2    1
# 3  Minnesota Timberwolves  128.7  114.5   98.7    1
# 4      Washington Wizards  117.7  109.6  110.4    1

# %%
nba_df.to_csv('nba_advanced_2024_data.csv', index=False)
